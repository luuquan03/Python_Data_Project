# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\cuanl\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\ed776e5a0a8c40ea9d5efbd800772ae52e140f3e (last modified on Tue Dec 23 09:22:57 2025).

# %%
# Create new dataframe
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2244777546640
# ID of df_altered:                 2244777546640
# Are the two dataframes the same?  True

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2246336773648
# ID of df_altered:                 2244367648592
# Are the two dataframes the same?  False

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
df.sample(n=5)
# Out:
#          job_title_short                                         job_title  \
# 429065     Data Engineer                               Data Engineer (A.I)
# 178524    Data Scientist               2023 intern - PhD Bid Data Research
# 125459     Data Engineer                        Lead Data Engineer (M/F/D)
# 158143  Business Analyst  Analyst Relations Project Manager Senior Analyst
# 321403    Data Scientist                                 Data Scientist IV
#
#                                  job_location               job_via  \
# 429065                             London, UK          via LinkedIn
# 178524                        Dublin, Ireland       via Trabajo.org
# 125459                                Austria          via LinkedIn
# 158143  Heredia Province, Heredia, Costa Rica  via BeBee Costa Rica
# 321403                        Gainesville, FL         via Uni Roles
#
#        job_schedule_type  job_work_from_home         search_location  \
# 429065         Full-time               False          United Kingdom
# 178524         Full-time               False                 Ireland
# 125459         Full-time               False                 Austria
# 158143         Full-time               False              Costa Rica
# 321403         Full-time               False  Florida, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 429065 2023-09-29 16:11:33                  False                 False
# 178524 2023-06-11 15:38:28                  False                 False
# 125459 2023-06-14 08:50:54                   True                 False
# 158143 2023-06-18 08:22:42                  False                 False
# 321403 2023-04-21 17:08:40                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 429065  United Kingdom        None              NaN              NaN
# 178524         Ireland        None              NaN              NaN
# 125459         Austria        None              NaN              NaN
# 158143      Costa Rica        None              NaN              NaN
# 321403   United States        None              NaN              NaN
#
#                      company_name  \
# 429065                  Synechron
# 178524             Huawei Ireland
# 125459     SO Digital Recruitment
# 158143                  Accenture
# 321403  The University of Florida
#
#                                                job_skills  \
# 429065        ['python', 'azure', 'airflow', 'terraform']
# 178524                      ['r', 'sas', 'sas', 'python']
# 125459  ['python', 'sql', 'nosql', 'azure', 'databrick...
# 158143                                     ['powerpoint']
# 321403  ['python', 'sql', 'aws', 'pandas', 'pytorch', ...
#
#                                           job_type_skills
# 429065  {'cloud': ['azure'], 'libraries': ['airflow'],...
# 178524  {'analyst_tools': ['sas'], 'programming': ['r'...
# 125459  {'cloud': ['azure', 'databricks'], 'libraries'...
# 158143                  {'analyst_tools': ['powerpoint']}
# 321403  {'cloud': ['aws'], 'libraries': ['pandas', 'py...

# %%
df.sample(frac=0.1, replace=False)
# Out:
#               job_title_short                              job_title  \
# 212633           Data Analyst                         Ingénieur Data
# 467848    Senior Data Analyst                    Senior Data Analyst
# 63112        Business Analyst                Junior Business Analyst
# 139071          Data Engineer                          Data Engineer
# 443624          Data Engineer                      AWS Data Engineer
# ...                       ...                                    ...
# 145106          Data Engineer  Data Engineer - Nederland - 6 maanden
# 779152    Senior Data Analyst                  Data Analytics Senior
# 667141       Business Analyst              Marketing Science Analyst
# 784202       Business Analyst            Lead Business Analyst & MIS
# 361828  Senior Data Scientist                  Senior Data Scientist
#
#                job_location            job_via job_schedule_type  \
# 212633        Paris, France          via BeBee         Full-time
# 467848  Deerfield Beach, FL          via BeBee         Full-time
# 63112             Australia       via LinkedIn        Contractor
# 139071  Copenhagen, Denmark  via BeBee Danmark         Full-time
# 443624             Anywhere           via Dice        Contractor
# ...                     ...                ...               ...
# 145106          Netherlands       via JobServe        Contractor
# 779152      Bloomington, IN          via BeBee         Full-time
# 667141            Argentina       via LinkedIn         Full-time
# 784202             Anywhere       via LinkedIn         Full-time
# 361828     Lisbon, Portugal    via Recruit.net         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 212633               False                   France 2023-11-25 22:13:20
# 467848               False   Florida, United States 2023-01-28 14:02:37
# 63112                False                Australia 2023-07-11 06:23:49
# 139071               False                  Denmark 2023-06-26 08:47:17
# 443624                True                   Canada 2023-04-04 16:33:26
# ...                    ...                      ...                 ...
# 145106               False              Netherlands 2023-07-13 08:16:44
# 779152               False  Illinois, United States 2023-09-12 05:02:01
# 667141               False                Argentina 2023-01-03 19:57:49
# 784202                True                    India 2023-01-03 06:25:19
# 361828               False                 Portugal 2023-07-27 23:44:42
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 212633                  False                 False         France
# 467848                  False                  True  United States
# 63112                   False                 False      Australia
# 139071                  False                 False        Denmark
# 443624                   True                 False         Canada
# ...                       ...                   ...            ...
# 145106                   True                 False    Netherlands
# 779152                  False                  True  United States
# 667141                   True                 False      Argentina
# 784202                  False                 False          India
# 361828                  False                 False       Portugal
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 212633        None              NaN              NaN
# 467848        None              NaN              NaN
# 63112         None              NaN              NaN
# 139071        None              NaN              NaN
# 443624        hour              NaN             57.5
# ...            ...              ...              ...
# 145106        None              NaN              NaN
# 779152        None              NaN              NaN
# 667141        None              NaN              NaN
# 784202        None              NaN              NaN
# 361828        None              NaN              NaN
#
#                         company_name  \
# 212633                      AB Tasty
# 467848   JM Family Enterprises, Inc.
# 63112                      The Onset
# 139071                       Workday
# 443624            KPI Partners, Inc.
# ...                              ...
# 145106    Global Enterprise Partners
# 779152                       myGwork
# 667141  Wunderman Thompson Argentina
# 784202       Quest Business Solution
# 361828                   Appy People
#
#                                                job_skills  \
# 212633  ['javascript', 'golang', 'java', 'python', 'ph...
# 467848  ['sql', 'sql server', 'oracle', 'azure', 'outl...
# 63112                              ['jira', 'confluence']
# 139071  ['python', 'java', 'sql', 'nosql', 'aws', 'gcp...
# 443624  ['python', 'sql', 'nosql', 'r', 'dynamodb', 'a...
# ...                                                   ...
# 145106  ['python', 'powershell', 'azure', 'power bi', ...
# 779152   ['sql', 'sas', 'sas', 'python', 'excel', 'flow']
# 667141                            ['tableau', 'power bi']
# 784202  ['python', 'sql', 'sas', 'sas', 'r', 'azure', ...
# 361828                                               None
#
#                                           job_type_skills
# 212633  {'cloud': ['gcp', 'bigquery'], 'other': ['kube...
# 467848  {'analyst_tools': ['outlook', 'sharepoint'], '...
# 63112                   {'async': ['jira', 'confluence']}
# 139071  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 443624  {'analyst_tools': ['excel', 'tableau', 'sheets...
# ...                                                   ...
# 145106  {'analyst_tools': ['power bi', 'qlik'], 'cloud...
# 779152  {'analyst_tools': ['sas', 'excel'], 'other': [...
# 667141         {'analyst_tools': ['tableau', 'power bi']}
# 784202  {'analyst_tools': ['sas', 'excel', 'powerpoint...
# 361828                                               None
#
# [78574 rows x 17 columns]
