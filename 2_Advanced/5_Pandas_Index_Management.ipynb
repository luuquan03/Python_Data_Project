# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df.sample(3)
# Out:
#          job_title_short                                       job_title  \
# 296955  Business Analyst             Lead BI Analyst (Japanese-speaking)
# 537482      Data Analyst  Data Analyst - Tire Warranty Quality Assurance
# 117342      Data Analyst                         Data Analyst SQL Python
#
#        job_location       job_via job_schedule_type  job_work_from_home  \
# 296955     Anywhere  via LinkedIn              None                True
# 537482    White, GA  via Tarta.ai         Full-time               False
# 117342        Spain     via BeBee         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 296955        Malaysia 2023-03-29 17:36:30                   True
# 537482         Georgia 2023-02-14 19:49:52                  False
# 117342           Spain 2023-08-29 08:43:02                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 296955                 False       Malaysia        None              NaN
# 537482                 False  United States        None              NaN
# 117342                 False          Spain        None              NaN
#
#         salary_hour_avg      company_name  \
# 296955              NaN      EPAM Systems
# 537482              NaN        Toyo Tires
# 117342              NaN  Krell Consulting
#
#                                                job_skills  \
# 296955                                             ['go']
# 537482             ['matlab', 'sql', 'cognos', 'tableau']
# 117342  ['sql', 'python', 'r', 'oracle', 'azure', 'spa...
#
#                                           job_type_skills
# 296955                            {'programming': ['go']}
# 537482  {'analyst_tools': ['cognos', 'tableau'], 'prog...
# 117342  {'analyst_tools': ['excel', 'power bi'], 'clou...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.index.name

# %%
df.index.name = 'job_index'

# %%
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#           job_title_short                    job_title  \
# job_index
# 462607      Data Engineer   Cloud Data Engineer - 7216
# 116599      Data Engineer          Data Build Engineer
# 491407     Cloud Engineer  Customer Experience Analyst
#
#                                 job_location       job_via job_schedule_type  \
# job_index
# 462607                   Zürich, Switzerland  via LinkedIn         Full-time
# 116599     Taguig, Metro Manila, Philippines      via Jora         Full-time
# 491407                         Sheffield, UK   via Harnham         Full-time
#
#            job_work_from_home search_location     job_posted_date  \
# job_index
# 462607                  False     Switzerland 2023-07-19 14:39:05
# 116599                  False     Philippines 2023-05-17 08:30:09
# 491407                  False  United Kingdom 2023-03-18 11:15:33
#
#            job_no_degree_mention  job_health_insurance     job_country  \
# job_index
# 462607                      True                 False     Switzerland
# 116599                      True                 False     Philippines
# 491407                      True                 False  United Kingdom
#
#           salary_rate  salary_year_avg  salary_hour_avg      company_name  \
# job_index
# 462607           None              NaN              NaN  IT Di-Visions AG
# 116599           None              NaN              NaN             Globe
# 491407           None              NaN              NaN              Test
#
#                                                   job_skills  \
# job_index
# 462607     ['python', 'sql', 'scala', 'azure', 'databrick...
# 116599                                                  None
# 491407                         ['sas', 'sas', 'python', 'r']
#
#                                              job_type_skills
# job_index
# 462607     {'cloud': ['azure', 'databricks'], 'libraries'...
# 116599                                                  None
# 491407     {'analyst_tools': ['sas'], 'programming': ['sa...
